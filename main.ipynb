# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagoahl/dry-beans-classification/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dry Beans Multiclass classification

# %% [markdown]
# >[Dry Beans Multiclass classification](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=OANX5piQ0SRq)
#
# >[Libraries](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=NddORS8z0WY3)
#
# >[Data import & Description](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=rhefUzjS1Olc)
#
# >[Data preprocessing](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=Op3Qd4xh1NCi)
#
# >>[Data cleaning](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=aSlvcCNr1S_E)
#
# >>>[Duplicates dropping](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=FKzMPLJh1UUE)
#
# >>[Null data](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=WHVIDF241aCX)
#
# >>[Balancing the dataset: SMOTE](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=5tpV7-mP1iqv)
#
# >>[One-Hot-Encoding](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=iFwVCRie5FVm)
#
# >>[Drop over correlated features](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=3N2qUQZ26cot)
#
# >>[Data split & normalization](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=Cs3xJRLk88gy)
#
# >[Data-viz](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=w8hueOQ18Ndm)
#
# >[Train](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=1o581ec_9xJB)
#
# >[Test](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=4Z9wxI1gBprk)
#
# >[Model export](#folderId=1i_G_Caw9nHZHyPks7gD0dgqvUBzMaJCF&updateTitle=true&scrollTo=q1Ij5QaxG_hf)

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE

import warnings
import joblib

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data import & Description

# %%
df = pd.read_csv('/content/drive/MyDrive/cursos_platzi/Machine Learning con python/logistic-regression/dry-beans/data/Dry_Bean.csv')

# %%
df
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
print(f'The bean classes are {df["""Class"""].unique()}')
# Out:
# The bean classes are ['SEKER' 'BARBUNYA' 'BOMBAY' 'CALI' 'HOROZ' 'SIRA' 'DERMASON']

# %%
df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53048.284549    855.283459       320.141867       202.270714
# std     29324.095717    214.289696        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.303633       175.848170
# 50%     44652.000000    794.941000       296.883367       192.431733
# 75%     61332.000000    977.213000       376.495012       217.031741
# max    254616.000000   1985.370000       738.860154       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000  13611.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.750895   53768.200206     253.064220      0.749733
# std        0.246678      0.092002   29774.915817      59.177120      0.049086
# ...

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Duplicates dropping

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## Null data

# %%
df.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %% [markdown]
# ## Balancing the dataset: SMOTE

# %% [markdown]
# Notice how unbalanced is the dataset:

# %%
labels, counts = np.unique(df.Class, return_counts=True)

plt.figure(figsize=(10, 10))
plt.pie(counts, autopct='%1.1f%%', labels=labels)
plt.title('Dataset proportions')
plt.show()

# %%
sm = SMOTE(random_state=42)

# %%
X = df.drop('Class', axis=1)
y = df.Class

# %%
X_sm, y_sm = sm.fit_resample(X, y)

# %%
labels, counts = np.unique(y_sm, return_counts=True)

plt.figure(figsize=(10, 10))
plt.pie(counts, autopct='%1.1f%%', labels=labels)
plt.title('Dataset proportions')
plt.show()

# %% [markdown]
# ## One-Hot-Encoding

# %%
list(np.unique(y_sm))
# Out:
# ['BARBUNYA', 'BOMBAY', 'CALI', 'DERMASON', 'HOROZ', 'SEKER', 'SIRA']

# %%
y_sm.replace(['BARBUNYA', 'BOMBAY', 'CALI', 'DERMASON', 'HOROZ', 'SEKER', 'SIRA'], [i for i in range(len(np.unique(y_sm)))])
# Out:
# 0        5
# 1        5
# 2        5
# 3        5
# 4        5
#         ..
# 24817    6
# 24818    6
# 24819    6
# 24820    6
# 24821    6
# Name: Class, Length: 24822, dtype: int64

# %% [markdown]
# ## Drop over correlated features

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(data=df.corr(), cmap='coolwarm', mask=np.triu(df.corr()), annot=True)
plt.show()

# %% [markdown]
# We observe that `ConvexArea` is deeply correlated with `Area`, `Perimeter`, `MajorAxisLength` and `MinorAxisLength`. `EquivDiameter` is also over correlated with several features. So we will drop both features.

# %%
X_sm.drop(['ConvexArea', 'EquivDiameter'], axis=1, inplace=True)

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(data=X_sm.corr(), cmap='coolwarm', mask=np.triu(X_sm.corr()), annot=True)
plt.show()

# %% [markdown]
# ## Data split & normalization

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, random_state=42, shuffle=True, test_size=0.2)

# %%
sc = StandardScaler()
sc.fit_transform(X_train)
sc.transform(X_test)

# %% [markdown]
# # Data-viz

# %%
sns.pairplot(df, hue='Class', corner=True, palette='coolwarm')
plt.show()

# %% [markdown]
# # Train

# %%
model = LogisticRegression(penalty='l2', verbose=1, n_jobs=-1)

# %%
model.get_params().keys()
# Out:
# dict_keys(['C', 'class_weight', 'dual', 'fit_intercept', 'intercept_scaling', 'l1_ratio', 'max_iter', 'multi_class', 'n_jobs', 'penalty', 'random_state', 'solver', 'tol', 'verbose', 'warm_start'])

# %%
LogisticRegression().solver
# Out:
# 'lbfgs'

# %%
params = {
    'solver':['lbfgs', 'newton-cg', 'liblinear', 'sag'],
    'multi_class':['ovr', 'multinomial']
}

# %%
clf = GridSearchCV(
    model,
    param_grid=params,
    scoring=f1_score,
    cv=5
)

# %%
clf.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    2.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    8.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# ...

# %%
model = clf.best_estimator_

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # Test

# %%
print(f'The model accuracy is: {np.round(accuracy_score(y_test, y_pred), decimals=3)*100}%')
# Out:
# The model accuracy is: 91.9%

# %%
print(f'The model f1 score is: {np.round(f1_score(y_test, y_pred, average="""weighted"""), decimals=3)*100}%')
# Out:
# The model f1 score is: 91.9%

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)

plt.figure(figsize=(12, 12))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap='coolwarm')
plt.xticks(rotation=45)
plt.suptitle('Confusion Matrix')
plt.show()

# %% [markdown]
# # Model export

# %%
joblib.dump(model, '/content/drive/MyDrive/cursos_platzi/Machine Learning con python/logistic-regression/dry-beans/models/model.pkl')
